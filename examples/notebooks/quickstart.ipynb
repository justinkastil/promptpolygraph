# %% [markdown]
# # PromptPolygraph quickstart
#
# Run the bundled offline mock demo end to end. No API key required.
#
# Open in Colab: replace `<owner>/<repo>` with the repository path and click the badge generated by
# `https://colab.research.google.com/github/<owner>/<repo>/blob/main/examples/notebooks/quickstart.ipynb`
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/justinkastil/promptpolygraph/blob/main/examples/notebooks/quickstart.ipynb)

# %% [markdown]
# ## 1. Install

# %%
# !pip install promptpolygraph

# %% [markdown]
# ## 2. Run the offline mock demo
#
# `--mock` uses a built-in demo target, so this runs fully offline. The example config, corpus,
# rubric, and personas ship with the package under `examples/everyday_assistant/`.

# %%
# !polygraph all --config examples/everyday_assistant/config.yaml --mock --format md

# %% [markdown]
# The markdown report is written under `polygraph_out/`. Drop `--mock` and configure a real
# adapter in `config.yaml` to evaluate your own system.
